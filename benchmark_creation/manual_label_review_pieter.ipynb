# %%
# ─────────────────────────────────────────────────────────────
# ✅ Manual Label Review – Troubles Dataset
# Loads all rows (all label categories), shows original + translation
# ─────────────────────────────────────────────────────────────

import pandas as pd

# === CONFIG ===
BATCH_SIZE = 150  # Adjust as needed
LABEL_PATH = "../data/middle/pieter/pieter_labeled_sample.csv"

# === Load and sort ===
df = pd.read_csv(LABEL_PATH)
df = df.sort_values(by='video_id').reset_index(drop=True)

# === Take the first batch ===
batch_df = df.iloc[:BATCH_SIZE].copy()
batch_df = batch_df[['video_id', 'original_text', 'translated_text', 'emoji_only', 'manual_label']]

# === Display table ===
print("⬇️ Previewing first", BATCH_SIZE, "rows (with GPT moral labels)")
batch_df.style.set_properties(
    subset=['original_text', 'translated_text'],
    **{'white-space': 'pre-wrap'}
)
# Out:
# ⬇️ Previewing first 150 rows (with GPT moral labels)
# <style type="text/css">
# #T_7114e_row0_col1, #T_7114e_row0_col2, #T_7114e_row1_col1, #T_7114e_row1_col2, #T_7114e_row2_col1, #T_7114e_row2_col2, #T_7114e_row3_col1, #T_7114e_row3_col2, #T_7114e_row4_col1, #T_7114e_row4_col2, #T_7114e_row5_col1, #T_7114e_row5_col2, #T_7114e_row6_col1, #T_7114e_row6_col2, #T_7114e_row7_col1, #T_7114e_row7_col2, #T_7114e_row8_col1, #T_7114e_row8_col2, #T_7114e_row9_col1, #T_7114e_row9_col2, #T_7114e_row10_col1, #T_7114e_row10_col2, #T_7114e_row11_col1, #T_7114e_row11_col2, #T_7114e_row12_col1, #T_7114e_row12_col2, #T_7114e_row13_col1, #T_7114e_row13_col2, #T_7114e_row14_col1, #T_7114e_row14_col2, #T_7114e_row15_col1, #T_7114e_row15_col2, #T_7114e_row16_col1, #T_7114e_row16_col2, #T_7114e_row17_col1, #T_7114e_row17_col2, #T_7114e_row18_col1, #T_7114e_row18_col2, #T_7114e_row19_col1, #T_7114e_row19_col2, #T_7114e_row20_col1, #T_7114e_row20_col2, #T_7114e_row21_col1, #T_7114e_row21_col2, #T_7114e_row22_col1, #T_7114e_row22_col2, #T_7114e_row23_col1, #T_7114e_row23_col2, #T_7114e_row24_col1, #T_7114e_row24_col2, #T_7114e_row25_col1, #T_7114e_row25_col2, #T_7114e_row26_col1, #T_7114e_row26_col2, #T_7114e_row27_col1, #T_7114e_row27_col2, #T_7114e_row28_col1, #T_7114e_row28_col2, #T_7114e_row29_col1, #T_7114e_row29_col2, #T_7114e_row30_col1, #T_7114e_row30_col2, #T_7114e_row31_col1, #T_7114e_row31_col2, #T_7114e_row32_col1, #T_7114e_row32_col2, #T_7114e_row33_col1, #T_7114e_row33_col2, #T_7114e_row34_col1, #T_7114e_row34_col2, #T_7114e_row35_col1, #T_7114e_row35_col2, #T_7114e_row36_col1, #T_7114e_row36_col2, #T_7114e_row37_col1, #T_7114e_row37_col2, #T_7114e_row38_col1, #T_7114e_row38_col2, #T_7114e_row39_col1, #T_7114e_row39_col2, #T_7114e_row40_col1, #T_7114e_row40_col2, #T_7114e_row41_col1, #T_7114e_row41_col2, #T_7114e_row42_col1, #T_7114e_row42_col2, #T_7114e_row43_col1, #T_7114e_row43_col2, #T_7114e_row44_col1, #T_7114e_row44_col2, #T_7114e_row45_col1, #T_7114e_row45_col2, #T_7114e_row46_col1, #T_7114e_row46_col2, #T_7114e_row47_col1, #T_7114e_row47_col2, #T_7114e_row48_col1, #T_7114e_row48_col2, #T_7114e_row49_col1, #T_7114e_row49_col2, #T_7114e_row50_col1, #T_7114e_row50_col2, #T_7114e_row51_col1, #T_7114e_row51_col2, #T_7114e_row52_col1, #T_7114e_row52_col2, #T_7114e_row53_col1, #T_7114e_row53_col2, #T_7114e_row54_col1, #T_7114e_row54_col2, #T_7114e_row55_col1, #T_7114e_row55_col2, #T_7114e_row56_col1, #T_7114e_row56_col2, #T_7114e_row57_col1, #T_7114e_row57_col2, #T_7114e_row58_col1, #T_7114e_row58_col2, #T_7114e_row59_col1, #T_7114e_row59_col2, #T_7114e_row60_col1, #T_7114e_row60_col2, #T_7114e_row61_col1, #T_7114e_row61_col2, #T_7114e_row62_col1, #T_7114e_row62_col2, #T_7114e_row63_col1, #T_7114e_row63_col2, #T_7114e_row64_col1, #T_7114e_row64_col2, #T_7114e_row65_col1, #T_7114e_row65_col2, #T_7114e_row66_col1, #T_7114e_row66_col2, #T_7114e_row67_col1, #T_7114e_row67_col2, #T_7114e_row68_col1, #T_7114e_row68_col2, #T_7114e_row69_col1, #T_7114e_row69_col2, #T_7114e_row70_col1, #T_7114e_row70_col2, #T_7114e_row71_col1, #T_7114e_row71_col2, #T_7114e_row72_col1, #T_7114e_row72_col2, #T_7114e_row73_col1, #T_7114e_row73_col2, #T_7114e_row74_col1, #T_7114e_row74_col2, #T_7114e_row75_col1, #T_7114e_row75_col2, #T_7114e_row76_col1, #T_7114e_row76_col2, #T_7114e_row77_col1, #T_7114e_row77_col2, #T_7114e_row78_col1, #T_7114e_row78_col2, #T_7114e_row79_col1, #T_7114e_row79_col2, #T_7114e_row80_col1, #T_7114e_row80_col2, #T_7114e_row81_col1, #T_7114e_row81_col2, #T_7114e_row82_col1, #T_7114e_row82_col2, #T_7114e_row83_col1, #T_7114e_row83_col2, #T_7114e_row84_col1, #T_7114e_row84_col2, #T_7114e_row85_col1, #T_7114e_row85_col2, #T_7114e_row86_col1, #T_7114e_row86_col2, #T_7114e_row87_col1, #T_7114e_row87_col2, #T_7114e_row88_col1, #T_7114e_row88_col2, #T_7114e_row89_col1, #T_7114e_row89_col2, #T_7114e_row90_col1, #T_7114e_row90_col2, #T_7114e_row91_col1, #T_7114e_row91_col2, #T_7114e_row92_col1, #T_7114e_row92_col2, #T_7114e_row93_col1, #T_7114e_row93_col2, #T_7114e_row94_col1, #T_7114e_row94_col2, #T_7114e_row95_col1, #T_7114e_ ...
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_7114e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7114e_level0_col0" class="col_heading level0 col0" >video_id</th>
#       <th id="T_7114e_level0_col1" class="col_heading level0 col1" >original_text</th>
#       <th id="T_7114e_level0_col2" class="col_heading level0 col2" >translated_text</th>
#       <th id="T_7114e_level0_col3" class="col_heading level0 col3" >emoji_only</th>
#       <th id="T_7114e_level0_col4" class="col_heading level0 col4" >manual_label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7114e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7114e_row0_col0" class="data row0 col0" >https://www.tiktok.com/@thepieterkriel/video/7479652795608567046</td>
#       <td id="T_7114e_row0_col1" class="data row0 col1" >it's the same issue in the black community</td>
#       <td id="T_7114e_row0_col2" class="data row0 col2" >it's the same issue in the black community</td>
#       <td id="T_7114e_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_7114e_row0_col4" class="data row0 col4" >Middle</td>
#     </tr>
#     <tr>
#       <th id="T_7114e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7114e_row1_col0" class="data row1 col0" >https://www.tiktok.com/@thepieterkriel/video/7479652795608567046</td>
#       <td id="T_7114e_row1_col1" class="data row1 col1" >Racism is taught</td>
#       <td id="T_7114e_row1_col2" class="data row1 col2" >Racism is taught</td>
#       <td id="T_7114e_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML

# === Load data ===
LABEL_PATH = "../data/middle/pieter/pieter_labeled_sample.csv"
df = pd.read_csv(LABEL_PATH)

# === Ensure label columns exist ===
if 'manual_label_new' not in df.columns:
    df['manual_label_new'] = df['manual_label']
if 'video_moral_label' not in df.columns:
    df['video_moral_label'] = "Unclear"

# === Sort and prepare ===
df = df.sort_values(by='video_id').reset_index(drop=True)
video_ids = df['video_id'].unique().tolist()
video_pointer = {'index': 0}

label_options = ["Ubuntu", "Chaos", "Middle", "Unclear"]
comment_dropdowns = {}
video_dropdown = None

# === Save changes made via dropdowns
def save_current_labels():
    current_video_id = video_ids[video_pointer['index']]
    current_comments = df[df['video_id'] == current_video_id]
    for i, row in current_comments.iterrows():
        df.at[i, 'manual_label_new'] = comment_dropdowns[i].value
    df.loc[df['video_id'] == current_video_id, 'video_moral_label'] = video_dropdown.value

# === Display video screen
def display_video(video_idx):
    clear_output()
    video_id = video_ids[video_idx]
    video_comments = df[df['video_id'] == video_id]
    print(f"📹 Video {video_idx+1} of {len(video_ids)}")

    # Top nav
    nav_buttons = []
    def make_nav_button(i, current_idx):
        style = {'button_color': '#1a73e8'} if i == current_idx else {}
        button = widgets.Button(description=f"Video {i+1}", layout=widgets.Layout(width='80px'), style=style)
        def on_click(b):
            save_current_labels()
            video_pointer['index'] = i
            display_video(i)
        button.on_click(on_click)
        return button

    for i in range(len(video_ids)):
        nav_buttons.append(make_nav_button(i, video_idx))
    display(widgets.HBox(nav_buttons))

    # Video link
    display(HTML(f'<b>🔗 Video Link:</b> <a href="{video_id}" target="_blank">{video_id}</a>'))

    # Video-level dropdown
    global video_dropdown
    video_dropdown = widgets.Dropdown(
        options=label_options,
        value=video_comments['video_moral_label'].iloc[0],
        description="Video Label:",
        layout=widgets.Layout(width='250px')
    )
    display(video_dropdown)

    # Comments
    box_list = []
    for i, row in video_comments.iterrows():
        comment_text = f"""
        <b>Row {i}</b><br>
        <b>Original:</b> {row['original_text']}<br>
        <b>Translated:</b> {row['translated_text']}<br>
        <b>Emojis:</b> {row['emoji_only']}
        """
        comment_html = widgets.HTML(value=comment_text)
        dd = widgets.Dropdown(options=label_options, value=row['manual_label_new'], layout=widgets.Layout(width='150px'))
        comment_dropdowns[i] = dd
        box_list.append(widgets.HBox([comment_html, dd]))
    display(widgets.VBox(box_list))

    # Prev/Next
    prev_button = widgets.Button(description="⬅ Previous")
    next_button = widgets.Button(description="Next ➡")

    def on_prev(b):
        if video_pointer['index'] > 0:
            save_current_labels()
            video_pointer['index'] -= 1
            display_video(video_pointer['index'])

    def on_next(b):
        if video_pointer['index'] < len(video_ids) - 1:
            save_current_labels()
            video_pointer['index'] += 1
            display_video(video_pointer['index'])

    prev_button.on_click(on_prev)
    next_button.on_click(on_next)

    display(widgets.HBox([prev_button, next_button]))

# 🔄 Launch UI
display_video(video_pointer['index'])
# Out:
# HBox(children=(Button(description='Video 1', layout=Layout(width='80px'), style=ButtonStyle()), Button(descrip…
# <b>🔗 Video Link:</b> <a href="https://www.tiktok.com/@thepieterkriel/video/7512385669453417734" target="_blank">https://www.tiktok.com/@thepieterkriel/video/7512385669453417734</a>
# Dropdown(description='Video Label:', index=3, layout=Layout(width='250px'), options=('Ubuntu', 'Chaos', 'Middl…
# VBox(children=(HBox(children=(HTML(value='\n        <b>Row 128</b><br>\n        <b>Original:</b> I like this, …
# HBox(children=(Button(description='⬅ Previous', style=ButtonStyle()), Button(description='Next ➡', style=Butto…

# %%
# Review full table before saving
display(df[['video_id', 'original_text', 'translated_text', 'manual_label', 'manual_label_new', 'video_moral_label']])

# Save button
save_button = widgets.Button(description="💾 Save to CSV")

def on_save(b):
    df.to_csv("../data/middle/pieter/pieter_manual_review.csv", index=False)
    print("✅ Saved to pieter_manual_review.csv")

save_button.on_click(on_save)
display(save_button)
# Out:
#                                               video_id  \
# 0    https://www.tiktok.com/@thepieterkriel/video/7...
# 1    https://www.tiktok.com/@thepieterkriel/video/7...
# 2    https://www.tiktok.com/@thepieterkriel/video/7...
# 3    https://www.tiktok.com/@thepieterkriel/video/7...
# 4    https://www.tiktok.com/@thepieterkriel/video/7...
# ..                                                 ...
# 145  https://www.tiktok.com/@thepieterkriel/video/7...
# 146  https://www.tiktok.com/@thepieterkriel/video/7...
# 147  https://www.tiktok.com/@thepieterkriel/video/7...
# 148  https://www.tiktok.com/@thepieterkriel/video/7...
# 149  https://www.tiktok.com/@thepieterkriel/video/7...
#
#                                          original_text  \
# 0           it's the same issue in the black community
# 1                                     Racism is taught
# 2                                      GOD bless you,😊
# 3    💙VIVA DA💙VIVA DA💙VIVA DA💙VIVA DA💙VIVA DA💙VIVA ...
# 4                               you are brave and wise
# ..                                                 ...
# 145  Corruption has done enormous damage Vusi, bett...
# 146       As South Africans we are not angry enough 🤞🏾
# 147                                                  🫡
# 148  khuphuka lapho mfana bayoze bakuvume ngeqiniso...
# 149                             the truth must be told
#
#                                        translated_text manual_label  \
# 0           it's the same issue in the black community       Middle
# 1                                     Racism is taught       Middle
# 2                                       GOD bless you,       Ubuntu
# 3    VIVA DAVIVA DAVIVA DAVIVA DAVIVA DAVIVA DAVIVA...      Unclear
# 4                               you are brave and wise       Ubuntu
# ..                                                 ...          ...
# 145  Corruption has done enormous damage Vusi, bett...       Middle
# 146          As South Africans we are not angry enough       Middle
# 147                                                NaN      Unclear
# 148  Go up when the boy will let you know about the...      Unclear
# 149                             the truth must be told       Middle
#
#     manual_label_new video_moral_label
# 0             Middle            Middle
# 1             Middle            Middle
# 2             Ubuntu            Middle
# 3             Middle            Middle
# 4             Ubuntu            Middle
# ..               ...               ...
# 145           Middle           Unclear
# 146           Middle           Unclear
# 147          Unclear           Unclear
# 148          Unclear           Unclear
# 149           Middle           Unclear
#
# [150 rows x 6 columns]
# Button(description='💾 Save to CSV', style=ButtonStyle())

# %%
# === Preview your work before saving ===
def preview_labels():
    save_current_labels()
    preview_df = df[['video_id', 'original_text', 'manual_label', 'manual_label_new', 'video_moral_label']].copy()
    display(preview_df.head(150))  # Show all

preview_labels()
# Out:
#                                               video_id  \
# 0    https://www.tiktok.com/@thepieterkriel/video/7...
# 1    https://www.tiktok.com/@thepieterkriel/video/7...
# 2    https://www.tiktok.com/@thepieterkriel/video/7...
# 3    https://www.tiktok.com/@thepieterkriel/video/7...
# 4    https://www.tiktok.com/@thepieterkriel/video/7...
# ..                                                 ...
# 145  https://www.tiktok.com/@thepieterkriel/video/7...
# 146  https://www.tiktok.com/@thepieterkriel/video/7...
# 147  https://www.tiktok.com/@thepieterkriel/video/7...
# 148  https://www.tiktok.com/@thepieterkriel/video/7...
# 149  https://www.tiktok.com/@thepieterkriel/video/7...
#
#                                          original_text manual_label  \
# 0           it's the same issue in the black community       Middle
# 1                                     Racism is taught       Middle
# 2                                      GOD bless you,😊       Ubuntu
# 3    💙VIVA DA💙VIVA DA💙VIVA DA💙VIVA DA💙VIVA DA💙VIVA ...      Unclear
# 4                               you are brave and wise       Ubuntu
# ..                                                 ...          ...
# 145  Corruption has done enormous damage Vusi, bett...       Middle
# 146       As South Africans we are not angry enough 🤞🏾       Middle
# 147                                                  🫡      Unclear
# 148  khuphuka lapho mfana bayoze bakuvume ngeqiniso...      Unclear
# 149                             the truth must be told       Middle
#
#     manual_label_new video_moral_label
# 0             Middle            Middle
# 1             Middle            Middle
# 2             Ubuntu            Middle
# 3             Middle            Middle
# 4             Ubuntu            Middle
# ..               ...               ...
# 145           Middle            Middle
# 146            Chaos            Middle
# 147           Middle            Middle
# 148           Ubuntu            Middle
# 149           Middle            Middle
#
# [150 rows x 5 columns]

# %%
# === Save final CSV manually when ready ===
def save_labels():
    save_current_labels()
    SAVE_PATH = "../data/middle/pieter/pieter_manual_review.csv"
    df.to_csv(SAVE_PATH, index=False)
    print(f"✅ Saved to {SAVE_PATH}")


save_labels()
# Out:
# ✅ Saved to ../data/middle/pieter/pieter_manual_review.csv
