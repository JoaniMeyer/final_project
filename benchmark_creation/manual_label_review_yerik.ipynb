# %%
# ─────────────────────────────────────────────────────────────
# ✅ Manual Label Review – Troubles Dataset
# Loads all rows (all label categories), shows original + translation
# ─────────────────────────────────────────────────────────────

import pandas as pd

# === CONFIG ===
BATCH_SIZE = 150  # Adjust as needed
LABEL_PATH = "../data/ubuntu/yerik/yerik_labeled_sample.csv"

# === Load and sort ===
df = pd.read_csv(LABEL_PATH)
df = df.sort_values(by='video_id').reset_index(drop=True)

# === Take the first batch ===
batch_df = df.iloc[:BATCH_SIZE].copy()
batch_df = batch_df[['video_id', 'original_text', 'translated_text', 'emoji_only', 'manual_label']]

# === Display table ===
print("⬇️ Previewing first", BATCH_SIZE, "rows (with GPT moral labels)")
batch_df.style.set_properties(
    subset=['original_text', 'translated_text'],
    **{'white-space': 'pre-wrap'}
)
# Out:
# ⬇️ Previewing first 150 rows (with GPT moral labels)
# <style type="text/css">
# #T_47b3c_row0_col1, #T_47b3c_row0_col2, #T_47b3c_row1_col1, #T_47b3c_row1_col2, #T_47b3c_row2_col1, #T_47b3c_row2_col2, #T_47b3c_row3_col1, #T_47b3c_row3_col2, #T_47b3c_row4_col1, #T_47b3c_row4_col2, #T_47b3c_row5_col1, #T_47b3c_row5_col2, #T_47b3c_row6_col1, #T_47b3c_row6_col2, #T_47b3c_row7_col1, #T_47b3c_row7_col2, #T_47b3c_row8_col1, #T_47b3c_row8_col2, #T_47b3c_row9_col1, #T_47b3c_row9_col2, #T_47b3c_row10_col1, #T_47b3c_row10_col2, #T_47b3c_row11_col1, #T_47b3c_row11_col2, #T_47b3c_row12_col1, #T_47b3c_row12_col2, #T_47b3c_row13_col1, #T_47b3c_row13_col2, #T_47b3c_row14_col1, #T_47b3c_row14_col2, #T_47b3c_row15_col1, #T_47b3c_row15_col2, #T_47b3c_row16_col1, #T_47b3c_row16_col2, #T_47b3c_row17_col1, #T_47b3c_row17_col2, #T_47b3c_row18_col1, #T_47b3c_row18_col2, #T_47b3c_row19_col1, #T_47b3c_row19_col2, #T_47b3c_row20_col1, #T_47b3c_row20_col2, #T_47b3c_row21_col1, #T_47b3c_row21_col2, #T_47b3c_row22_col1, #T_47b3c_row22_col2, #T_47b3c_row23_col1, #T_47b3c_row23_col2, #T_47b3c_row24_col1, #T_47b3c_row24_col2, #T_47b3c_row25_col1, #T_47b3c_row25_col2, #T_47b3c_row26_col1, #T_47b3c_row26_col2, #T_47b3c_row27_col1, #T_47b3c_row27_col2, #T_47b3c_row28_col1, #T_47b3c_row28_col2, #T_47b3c_row29_col1, #T_47b3c_row29_col2, #T_47b3c_row30_col1, #T_47b3c_row30_col2, #T_47b3c_row31_col1, #T_47b3c_row31_col2, #T_47b3c_row32_col1, #T_47b3c_row32_col2, #T_47b3c_row33_col1, #T_47b3c_row33_col2, #T_47b3c_row34_col1, #T_47b3c_row34_col2, #T_47b3c_row35_col1, #T_47b3c_row35_col2, #T_47b3c_row36_col1, #T_47b3c_row36_col2, #T_47b3c_row37_col1, #T_47b3c_row37_col2, #T_47b3c_row38_col1, #T_47b3c_row38_col2, #T_47b3c_row39_col1, #T_47b3c_row39_col2, #T_47b3c_row40_col1, #T_47b3c_row40_col2, #T_47b3c_row41_col1, #T_47b3c_row41_col2, #T_47b3c_row42_col1, #T_47b3c_row42_col2, #T_47b3c_row43_col1, #T_47b3c_row43_col2, #T_47b3c_row44_col1, #T_47b3c_row44_col2, #T_47b3c_row45_col1, #T_47b3c_row45_col2, #T_47b3c_row46_col1, #T_47b3c_row46_col2, #T_47b3c_row47_col1, #T_47b3c_row47_col2, #T_47b3c_row48_col1, #T_47b3c_row48_col2, #T_47b3c_row49_col1, #T_47b3c_row49_col2, #T_47b3c_row50_col1, #T_47b3c_row50_col2, #T_47b3c_row51_col1, #T_47b3c_row51_col2, #T_47b3c_row52_col1, #T_47b3c_row52_col2, #T_47b3c_row53_col1, #T_47b3c_row53_col2, #T_47b3c_row54_col1, #T_47b3c_row54_col2, #T_47b3c_row55_col1, #T_47b3c_row55_col2, #T_47b3c_row56_col1, #T_47b3c_row56_col2, #T_47b3c_row57_col1, #T_47b3c_row57_col2, #T_47b3c_row58_col1, #T_47b3c_row58_col2, #T_47b3c_row59_col1, #T_47b3c_row59_col2, #T_47b3c_row60_col1, #T_47b3c_row60_col2, #T_47b3c_row61_col1, #T_47b3c_row61_col2, #T_47b3c_row62_col1, #T_47b3c_row62_col2, #T_47b3c_row63_col1, #T_47b3c_row63_col2, #T_47b3c_row64_col1, #T_47b3c_row64_col2, #T_47b3c_row65_col1, #T_47b3c_row65_col2, #T_47b3c_row66_col1, #T_47b3c_row66_col2, #T_47b3c_row67_col1, #T_47b3c_row67_col2, #T_47b3c_row68_col1, #T_47b3c_row68_col2, #T_47b3c_row69_col1, #T_47b3c_row69_col2, #T_47b3c_row70_col1, #T_47b3c_row70_col2, #T_47b3c_row71_col1, #T_47b3c_row71_col2, #T_47b3c_row72_col1, #T_47b3c_row72_col2, #T_47b3c_row73_col1, #T_47b3c_row73_col2, #T_47b3c_row74_col1, #T_47b3c_row74_col2, #T_47b3c_row75_col1, #T_47b3c_row75_col2, #T_47b3c_row76_col1, #T_47b3c_row76_col2, #T_47b3c_row77_col1, #T_47b3c_row77_col2, #T_47b3c_row78_col1, #T_47b3c_row78_col2, #T_47b3c_row79_col1, #T_47b3c_row79_col2, #T_47b3c_row80_col1, #T_47b3c_row80_col2, #T_47b3c_row81_col1, #T_47b3c_row81_col2, #T_47b3c_row82_col1, #T_47b3c_row82_col2, #T_47b3c_row83_col1, #T_47b3c_row83_col2, #T_47b3c_row84_col1, #T_47b3c_row84_col2, #T_47b3c_row85_col1, #T_47b3c_row85_col2, #T_47b3c_row86_col1, #T_47b3c_row86_col2, #T_47b3c_row87_col1, #T_47b3c_row87_col2, #T_47b3c_row88_col1, #T_47b3c_row88_col2, #T_47b3c_row89_col1, #T_47b3c_row89_col2, #T_47b3c_row90_col1, #T_47b3c_row90_col2, #T_47b3c_row91_col1, #T_47b3c_row91_col2, #T_47b3c_row92_col1, #T_47b3c_row92_col2, #T_47b3c_row93_col1, #T_47b3c_row93_col2, #T_47b3c_row94_col1, #T_47b3c_row94_col2, #T_47b3c_row95_col1, #T_47b3c_ ...
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_47b3c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47b3c_level0_col0" class="col_heading level0 col0" >video_id</th>
#       <th id="T_47b3c_level0_col1" class="col_heading level0 col1" >original_text</th>
#       <th id="T_47b3c_level0_col2" class="col_heading level0 col2" >translated_text</th>
#       <th id="T_47b3c_level0_col3" class="col_heading level0 col3" >emoji_only</th>
#       <th id="T_47b3c_level0_col4" class="col_heading level0 col4" >manual_label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47b3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47b3c_row0_col0" class="data row0 col0" >https://www.tiktok.com/@yerik.jomei/video/7371510272684494085</td>
#       <td id="T_47b3c_row0_col1" class="data row0 col1" >zayaan reposted</td>
#       <td id="T_47b3c_row0_col2" class="data row0 col2" >zayaan reposted</td>
#       <td id="T_47b3c_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_47b3c_row0_col4" class="data row0 col4" >Unclear</td>
#     </tr>
#     <tr>
#       <th id="T_47b3c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47b3c_row1_col0" class="data row1 col0" >https://www.tiktok.com/@yerik.jomei/video/7371510272684494085</td>
#       <td id="T_47b3c_row1_col1" class="data row1 col1" >@Tebogo Mogashoa 😭</td>
#       <td id="T_47b3c_row1_col2" class="data row1 col2" >@Tebogo Mogashoa</td>
#       <td id="T_47b3c_row1_col3" class="data row1 col3" >😭</td>
#       <td id="T_47b3c_row1_col4" class="data row1 col4" >Unclear</td>

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML

# === Load data ===
LABEL_PATH = "../data/ubuntu/yerik/yerik_labeled_sample.csv"
df = pd.read_csv(LABEL_PATH)

# === Ensure label columns exist ===
if 'manual_label_new' not in df.columns:
    df['manual_label_new'] = df['manual_label']
if 'video_moral_label' not in df.columns:
    df['video_moral_label'] = "Unclear"

# === Sort and prepare ===
df = df.sort_values(by='video_id').reset_index(drop=True)
video_ids = df['video_id'].unique().tolist()
video_pointer = {'index': 0}

label_options = ["Ubuntu", "Chaos", "Middle", "Unclear"]
comment_dropdowns = {}
video_dropdown = None

# === Save changes made via dropdowns
def save_current_labels():
    current_video_id = video_ids[video_pointer['index']]
    current_comments = df[df['video_id'] == current_video_id]
    for i, row in current_comments.iterrows():
        df.at[i, 'manual_label_new'] = comment_dropdowns[i].value
    df.loc[df['video_id'] == current_video_id, 'video_moral_label'] = video_dropdown.value

# === Display video screen
def display_video(video_idx):
    clear_output()
    video_id = video_ids[video_idx]
    video_comments = df[df['video_id'] == video_id]
    print(f"📹 Video {video_idx+1} of {len(video_ids)}")

    # Top nav
    nav_buttons = []
    def make_nav_button(i, current_idx):
        style = {'button_color': '#1a73e8'} if i == current_idx else {}
        button = widgets.Button(description=f"Video {i+1}", layout=widgets.Layout(width='80px'), style=style)
        def on_click(b):
            save_current_labels()
            video_pointer['index'] = i
            display_video(i)
        button.on_click(on_click)
        return button

    for i in range(len(video_ids)):
        nav_buttons.append(make_nav_button(i, video_idx))
    display(widgets.HBox(nav_buttons))

    # Video link
    display(HTML(f'<b>🔗 Video Link:</b> <a href="{video_id}" target="_blank">{video_id}</a>'))

    # Video-level dropdown
    global video_dropdown
    video_dropdown = widgets.Dropdown(
        options=label_options,
        value=video_comments['video_moral_label'].iloc[0],
        description="Video Label:",
        layout=widgets.Layout(width='250px')
    )
    display(video_dropdown)

    # Comments
    box_list = []
    for i, row in video_comments.iterrows():
        comment_text = f"""
        <b>Row {i}</b><br>
        <b>Original:</b> {row['original_text']}<br>
        <b>Translated:</b> {row['translated_text']}<br>
        <b>Emojis:</b> {row['emoji_only']}
        """
        comment_html = widgets.HTML(value=comment_text)
        dd = widgets.Dropdown(options=label_options, value=row['manual_label_new'], layout=widgets.Layout(width='150px'))
        comment_dropdowns[i] = dd
        box_list.append(widgets.HBox([comment_html, dd]))
    display(widgets.VBox(box_list))

    # Prev/Next
    prev_button = widgets.Button(description="⬅ Previous")
    next_button = widgets.Button(description="Next ➡")

    def on_prev(b):
        if video_pointer['index'] > 0:
            save_current_labels()
            video_pointer['index'] -= 1
            display_video(video_pointer['index'])

    def on_next(b):
        if video_pointer['index'] < len(video_ids) - 1:
            save_current_labels()
            video_pointer['index'] += 1
            display_video(video_pointer['index'])

    prev_button.on_click(on_prev)
    next_button.on_click(on_next)

    display(widgets.HBox([prev_button, next_button]))

# 🔄 Launch UI
display_video(video_pointer['index'])
# Out:
# HBox(children=(Button(description='Video 1', layout=Layout(width='80px'), style=ButtonStyle()), Button(descrip…
# <b>🔗 Video Link:</b> <a href="https://www.tiktok.com/@yerik.jomei/video/7511779456135073080" target="_blank">https://www.tiktok.com/@yerik.jomei/video/7511779456135073080</a>
# Dropdown(description='Video Label:', layout=Layout(width='250px'), options=('Ubuntu', 'Chaos', 'Middle', 'Uncl…
# VBox(children=(HBox(children=(HTML(value='\n        <b>Row 129</b><br>\n        <b>Original:</b> 😂😂😂😂<br>\n   …
# HBox(children=(Button(description='⬅ Previous', style=ButtonStyle()), Button(description='Next ➡', style=Butto…

# %%
# === Preview your work before saving ===
def preview_labels():
    save_current_labels()
    preview_df = df[['video_id', 'original_text', 'manual_label', 'manual_label_new', 'video_moral_label']].copy()
    display(preview_df.head(150))  # Show all

preview_labels()
# Out:
#                                               video_id  \
# 0    https://www.tiktok.com/@yerik.jomei/video/7371...
# 1    https://www.tiktok.com/@yerik.jomei/video/7371...
# 2    https://www.tiktok.com/@yerik.jomei/video/7371...
# 3    https://www.tiktok.com/@yerik.jomei/video/7371...
# 4    https://www.tiktok.com/@yerik.jomei/video/7371...
# ..                                                 ...
# 145  https://www.tiktok.com/@yerik.jomei/video/7511...
# 146  https://www.tiktok.com/@yerik.jomei/video/7511...
# 147  https://www.tiktok.com/@yerik.jomei/video/7511...
# 148  https://www.tiktok.com/@yerik.jomei/video/7511...
# 149  https://www.tiktok.com/@yerik.jomei/video/7511...
#
#                                          original_text manual_label  \
# 0                                      zayaan reposted      Unclear
# 1                                   @Tebogo Mogashoa 😭      Unclear
# 2                                                 amen      Unclear
# 3                                                 @moo      Unclear
# 4    🤣🤣🤣 This is this is so wholesome and cute best...       Ubuntu
# ..                                                 ...          ...
# 145  I love the way it all leads back to Jesus our ...       Ubuntu
# 146                                            😂😂😂👌👌🥰🥰      Unclear
# 147                                     funny facts ❤️      Unclear
# 148  Thank you please, someone had to say it 😂😂😂😂🤷‍...       Ubuntu
# 149                      heelaaaaanggggg?😭😭😭🔥🔥🔥🔥🔥🔥🔥🔥🔥😂      Unclear
#
#     manual_label_new video_moral_label
# 0             Middle            Ubuntu
# 1             Middle            Ubuntu
# 2             Middle            Ubuntu
# 3             Middle            Ubuntu
# 4             Ubuntu            Ubuntu
# ..               ...               ...
# 145           Ubuntu            Ubuntu
# 146           Middle            Ubuntu
# 147           Middle            Ubuntu
# 148           Ubuntu            Ubuntu
# 149           Middle            Ubuntu
#
# [150 rows x 5 columns]

# %%
# === Save final CSV manually when ready ===
def save_labels():
    save_current_labels()
    SAVE_PATH = "../data/ubuntu/yerik/yerik_labeled_sample.csv"
    df.to_csv(SAVE_PATH, index=False)
    print(f"✅ Saved to {SAVE_PATH}")


save_labels()
# Out:
# ✅ Saved to ../data/ubuntu/yerik/yerik_labeled_sample.csv
